# %% [markdown]
# # Setting

# %%
# for colab

from google.colab import drive
import os

drive.mount('/content/drive')
main_dir = '/content/drive/MyDrive/Colab Notebooks/comtrade'

if not os.path.exists(main_dir):
    os.mkdir(main_dir)
    print(f"'{main_dir}' created.")
else:
    print(f"'{main_dir}' already exists.")

os.chdir(main_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/Colab Notebooks/comtrade' already exists.

# %%
subscription_key = '08c7##############'

down_dir = os.path.join(os.getcwd(), 'download')

if not os.path.exists(down_dir):
    os.mkdir(down_dir)
    print(f"'{down_dir}' created")
else:
    print(f"'{down_dir}' already exists")
# Out:
# '/content/drive/MyDrive/Colab Notebooks/comtrade/download' created

# %% [markdown]
# # Sample
#
# - 세 종류 벌크가 있는데, 딱 보니 Final로 받으면 될듯

# %%
# !pip install comtradeapicall --quiet

# %%
import comtradeapicall as cc

cc.convertCountryIso3ToCode('KOR')
# Out:
# '410'

# %% [markdown]
# ## Final

# %%
import comtradeapicall as cc

cc.getFinalDataBulkAvailability(subscription_key, typeCode='C', freqCode='M',
                                clCode='HS', period='202201', reporterCode=410, publishedDateFrom=None, publishedDateTo=None)
# Out:
#                                              fileUrl fileSize  \
# 0  https://comtradeapi.un.org/bulk/v1/file/410/89...  3.86 MB
#
#    isOriginalClassification  reporterCode freqCode typeCode  \
# 0                      True           410        M        C
#
#   classificationCode  refPeriodId  period       publicationDate partitionKey  \
# 0                 H6       202201  202201  2023-08-27T14:17:20Z          410
#
#                                               rowKey  \
# 0  8923cb7cd0d15e0fbb0e5130f83d54a8baaf14f75b1941...
#
#                            timestamp  \
# 0  2024-03-09T02:33:39.9651659+00:00
#
#                                              eTag
# 0  W/"datetime'2024-03-09T02%3A33%3A39.9651659Z'"

# %%
import comtradeapicall as cc

cc.bulkDownloadFinalFile(subscription_key, down_dir, typeCode='C', freqCode='M',
                         clCode='HS', period='202201', reporterCode=410, decompress=True)
# Out:
# COMTRADE-FINAL-CM410202201H6[2023-08-27] downloaded
# Total of 1 file(s) downloaded

# %%
import pandas as pd

sample_final = pd.read_csv(os.path.join(down_dir, 'COMTRADE-FINAL-CM410202201H6[2023-08-27].txt'), sep='	')

# %%
sample_final
# Out:
#               datasetCode typeCode freqCode  refPeriodId  refYear  refMonth  \
# 0       30410202201202100        C        M     20220101     2022         1
# 1       30410202201202100        C        M     20220101     2022         1
# 2       30410202201202100        C        M     20220101     2022         1
# 3       30410202201202100        C        M     20220101     2022         1
# 4       30410202201202100        C        M     20220101     2022         1
# ...                   ...      ...      ...          ...      ...       ...
# 199709  30410202201202100        C        M     20220101     2022         1
# 199710  30410202201202100        C        M     20220101     2022         1
# 199711  30410202201202100        C        M     20220101     2022         1
# 199712  30410202201202100        C        M     20220101     2022         1
# 199713  30410202201202100        C        M     20220101     2022         1
#
# ...

# %%
sample_final.iloc[0] # period, reporterCode, flowCode, partnerCode, classificationCdoe, comCode, primaryValue 정도?
# Out:
# datasetCode                 30410202201202100
# typeCode                                    C
# freqCode                                    M
# refPeriodId                          20220101
# refYear                                  2022
# refMonth                                    1
# period                                 202201
# reporterCode                              410
# flowCode                                    M
# partnerCode                               276
# partner2Code                                0
# classificationSearchCode                   HS
# classificationCode                         H6
# isOriginalClassification                    1
# cmdCode                                640359
# customsCode                               C00
# mosCode                                     0
# motCode                                     0
# qtyUnitCode                                -1
# qty                                       0.0
# ...

# %% [markdown]
# ## Final Classic

# %%
import comtradeapicall as cc

cc.bulkDownloadFinalClassicFile(subscription_key, down_dir, typeCode='C', freqCode='M',
                                clCode='HS', period='202201', reporterCode=410, decompress=True)
# Out:
# COMTRADE-FINALCLASSIC-CM410202201H6[2023-08-27] downloaded
# Total of 1 file(s) downloaded

# %%
import pandas as pd

sample_final_classic = pd.read_csv(os.path.join(down_dir, 'COMTRADE-FINALCLASSIC-CM410202201H6[2023-08-27].txt'), sep='	')

# %%
sample_final_classic
# Out:
#               datasetCode typeCode freqCode  refPeriodId  refYear  refMonth  \
# 0       30410202201202100        C        M     20220101     2022         1
# 1       30410202201202100        C        M     20220101     2022         1
# 2       30410202201202100        C        M     20220101     2022         1
# 3       30410202201202100        C        M     20220101     2022         1
# 4       30410202201202100        C        M     20220101     2022         1
# ...                   ...      ...      ...          ...      ...       ...
# 199709  30410202201202100        C        M     20220101     2022         1
# 199710  30410202201202100        C        M     20220101     2022         1
# 199711  30410202201202100        C        M     20220101     2022         1
# 199712  30410202201202100        C        M     20220101     2022         1
# 199713  30410202201202100        C        M     20220101     2022         1
#
# ...

# %%
sample_final_classic.iloc[0]
# Out:
# datasetCode                 30410202201202100
# typeCode                                    C
# freqCode                                    M
# refPeriodId                          20220101
# refYear                                  2022
# refMonth                                    1
# period                                 202201
# reporterCode                              410
# flowCode                                    M
# partnerCode                               276
# classificationSearchCode                   HS
# classificationCode                         H6
# isOriginalClassification                    1
# cmdCode                                640359
# qtyUnitCode                                -1
# qty                                       0.0
# isQtyEstimated                              0
# altQtyUnitCode                              8
# altQty                                   9.54
# isAltQtyEstimated                           0
# ...

# %%
set(sample_final.columns) - set(sample_final_classic.columns) # 얘도 충분하긴 함
# Out:
# {'customsCode', 'mosCode', 'motCode', 'partner2Code'}

# %% [markdown]
# ## Tariff Line

# %%
import comtradeapicall as cc

cc.bulkDownloadTarifflineFile(subscription_key, down_dir, typeCode='C', freqCode='M',
                              clCode='HS', period='202201', reporterCode=410, decompress=True)
# Out:
# COMTRADE-TARIFFLINE-CM410202201H6[2023-08-27] downloaded
# Total of 1 file(s) downloaded

# %%
import pandas as pd

sample_tariff_line = pd.read_csv(os.path.join(down_dir, 'COMTRADE-TARIFFLINE-CM410202201H6[2023-08-27].txt'), sep='	')
# Out:
# <ipython-input-36-ef5673005820>:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   sample_tariff_line = pd.read_csv(os.path.join(down_dir, 'COMTRADE-TARIFFLINE-CM410202201H6[2023-08-27].txt'), sep='	')

# %%
sample_tariff_line
# Out:
#               datasetCode typeCode freqCode  refPeriodId  period  \
# 0       30410202201202100        C        M     20220101  202201
# 1       30410202201202100        C        M     20220101  202201
# 2       30410202201202100        C        M     20220101  202201
# 3       30410202201202100        C        M     20220101  202201
# 4       30410202201202100        C        M     20220101  202201
# ...                   ...      ...      ...          ...     ...
# 120095  30410202201202100        C        M     20220101  202201
# 120096  30410202201202100        C        M     20220101  202201
# 120097  30410202201202100        C        M     20220101  202201
# 120098  30410202201202100        C        M     20220101  202201
# 120099  30410202201202100        C        M     20220101  202201
#
#         reporterCode flowCategory flowCode  partnerCode  partner2Code  ...  \
# 0                410            X        X          764            -1  ...
# ...

# %%
sample_tariff_line.iloc[0] # flowCode (수출입 방향) 없음
# Out:
# datasetCode           30410202201202100
# typeCode                              C
# freqCode                              M
# refPeriodId                    20220101
# period                           202201
# reporterCode                        410
# flowCategory                          X
# flowCode                              X
# partnerCode                         764
# partner2Code                         -1
# classificationCode                   H6
# cmdCode                          200830
# customsCode                          -1
# mosCode                              -1
# motCode                              -1
# qtyUnitCode                          -1
# qty                                 0.0
# altQtyUnitCode                       -1
# altQty                              0.0
# netWgt                              0.0
# grossWgt                            0.0
# cifValue                            NaN
# fobValue                        40640.0
# ...
